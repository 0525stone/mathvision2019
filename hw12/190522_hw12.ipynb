# %% [markdown]
# # HW12

# %% [markdown]
# ###### z = f(x,y) = (x+y)(xy+xy^2)
# ###### range : -2<=x<=2, -2<=y<=2

# %%
# Hessian matrix
H_f = np.array(((2*y+2*y*y, 2*x+4*x*y+2*y+3*y*y),(2*x+4*x*y+2*y+3*y*y,2*x*x+2*x+6*x*y)))

# %%
# %matplotlib notebook
# visualization of function z
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure(figsize=(10,8))
ax = fig.gca(projection='3d')

# Make data.
x_p=1
y_p=1
z_p=(x_p+y_p)*(x_p*y_p+x_p*y_p*y_p)
X = np.arange(-2, 2.05, 0.25)
Y = np.arange(-2, 2.05, 0.25)
Z , nothing= np.meshgrid(X,Y) # Z값을 행렬로 표현
for i in range(17):
    for j in range(17):
        x = X[i]
        y = Y[j]
        Z[i][j] = (x+y)*(x*y+x*y*y)
X,Y = np.meshgrid(X,Y) # visualization 할 때, Z 행렬의 위치별 해당 X,Y좌표

# Visualization
ax.scatter(x_p, y_p, z_p,s=10, marker='o',c='r')
ax.scatter(-1, -2, 0,s=10, marker='o',c='r')
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0,alpha=.4, antialiased=False)
#ax.scatter(x_p, y_p, 40,s=50, marker='o',c='r')

# Customize the z axis.
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# 연립방정식 -> 실패
from sympy import Symbol, solve, Eq

x_ = Symbol('x')
y_ = Symbol('y')

e1 = Eq((y_*(1+y_)*(2*x_+y_)),0)
e2 = Eq(x_*x_+2*x_*x_*y_+2*x_*y_+3*x_*y_*y_, 0)￼
solve([e1, e2], x_, y_)
# Out:
#   File "<ipython-input-59-401b6b2dc6b4>", line 8
#     e2 = Eq(x_*x_+2*x_*x_*y_+2*x_*y_+3*x_*y_*y_, 0)￼
#                                                    ^
# SyntaxError: invalid character in identifier

# %% [markdown]
# #### for the record I could not success using sympy
# ![title](failure.png)

# %%
# 직접 구함
# (0,0) (0,-1) (1,-1) (3/8,-3/4)
x=0
y=0
# Hessian matrix
H_f = np.array(((2*y+2*y*y, 2*x+4*x*y+2*y+3*y*y),(2*x+4*x*y+2*y+3*y*y,2*x*x+2*x+6*x*y)))


# eigen decomposition
w,v = np.linalg.eig(H_f)
print('x=',x,'y=',y)
print(w)
print(v)
# Out:
# x= 0 y= 0
# [ 0.  0.]
# [[ 1.  0.]
#  [ 0.  1.]]

# %%
# 직접 구함
# (0,0) (0,-1) (1,-1) (3/8,-3/4)
x=0
y=-1
# Hessian matrix
H_f = np.array(((2*y+2*y*y, 2*x+4*x*y+2*y+3*y*y),(2*x+4*x*y+2*y+3*y*y,2*x*x+2*x+6*x*y)))
#print(H_f)

# eigen decomposition
w,v = np.linalg.eig(H_f)
print('x=',x,'y=',y)
print(w)
print(v)
# Out:
# x= 0 y= -1
# [ 1. -1.]
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
# 직접 구함
# (0,0) (0,-1) (1,-1) (3/8,-3/4)
x=1
y=-1
# Hessian matrix
H_f = np.array(((2*y+2*y*y, 2*x+4*x*y+2*y+3*y*y),(2*x+4*x*y+2*y+3*y*y,2*x*x+2*x+6*x*y)))
#print(H_f)

# eigen decomposition
w,v = np.linalg.eig(H_f)
print('x=',x,'y=',y)
print(w)
print(v)
# Out:
# x= 1 y= -1
# [ 0.41421356 -2.41421356]
# [[ 0.92387953  0.38268343]
#  [-0.38268343  0.92387953]]

# %%
# 직접 구함
# (0,0) (0,-1) (1,-1) (3/8,-3/4)
x=3/8
y=-3/4
# Hessian matrix
H_f = np.array(((2*y+2*y*y, 2*x+4*x*y+2*y+3*y*y),(2*x+4*x*y+2*y+3*y*y,2*x*x+2*x+6*x*y)))
#print(H_f)

# eigen decomposition
w,v = np.linalg.eig(H_f)
print('x=',x,'y=',y)
print(w)
print(v)
# Out:
# x= 0.375 y= -0.75
# [-0.28125 -0.75   ]
# [[ 0.89442719  0.4472136 ]
#  [-0.4472136   0.89442719]]

# %%
# %matplotlib notebook
# visualization of function z
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure(figsize=(10,8))
ax = fig.gca(projection='3d')

# Make data.
x_p=1
y_p=1
z_p=(x_p+y_p)*(x_p*y_p+x_p*y_p*y_p)
X = np.arange(-2, 2.05, 0.25)
Y = np.arange(-2, 2.05, 0.25)
Z , nothing= np.meshgrid(X,Y) # Z값을 행렬로 표현
for i in range(17):
    for j in range(17):
        x = X[i]
        y = Y[j]
        Z[i][j] = (x+y)*(x*y+x*y*y)
X,Y = np.meshgrid(X,Y) # visualization 할 때, Z 행렬의 위치별 해당 X,Y좌표

# Visualization
ax.scatter(x_p, y_p, z_p,s=10, marker='o',c='r')
ax.scatter(0, 0, 0,s=10, marker='o',c='g')
ax.scatter(0, -1, 0,s=10, marker='o',c='b')
ax.scatter(1, -1, 0,s=10, marker='x',c='g')
ax.scatter(.375, -.75, 0.0263671875,s=10, marker='x',c='b')
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0,alpha=.4, antialiased=False)
#ax.scatter(x_p, y_p, 40,s=50, marker='o',c='r')

# Customize the z axis.
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
x= 1 # x= .375
y=-1 # y=-/75
z = (x+y)*(x*y+x*y*y)
print(z)
# Out:
# 0

# %%
x=1
y=1
# Hessian matrix
H_f = np.array(((2*y+2*y*y, 2*x+4*x*y+2*y+3*y*y),(2*x+4*x*y+2*y+3*y*y,2*x*x+2*x+6*x*y)))
print(H_f)

# eigen decomposition
w,v = np.linalg.eig(H_f)
print(w)
print(v)
# Out:
# [[ 4 11]
#  [11 10]]
# [ -4.40175425  18.40175425]
# [[-0.79470668 -0.60699365]
#  [ 0.60699365 -0.79470668]]

# %%
H_f
w,v = np.linalg.eig(H_f)

# %%
w
# Out:
# array([ -4.40175425,  18.40175425])

# %%
v
# Out:
# array([[-0.79470668, -0.60699365],
#        [ 0.60699365, -0.79470668]])

# %%
a = np.array(((1,2),(3,4)))
b = np.array(((6,7),(8,9)))
print(np.matmul(a,b))
print(np.dot(a,b))
# Out:
# [[22 25]
#  [50 57]]
# [[22 25]
#  [50 57]]

# %% [markdown]
# # 이전 자료

# %%
#24개 ' 
# %matplotlib notebook
n=8
# 완성!!!!!!!!!!!!!!!!
filename = '../../opencv/extra(sl)/3dv_tutorial-master/bin/test/triangulation.xyz'
f1 = open(filename, 'r')

#line = f1.readline()
#x_,y_,z_ = line.split()
x = np.array([])
y = np.array([])
z = np.array([])

for i in range(n):
 #   print(i)
    line = f1.readline()
 #   print(line)
    x_,y_,z_ = line.split()
    x = np.append(x,1*float(x_))   # 그냥 읽어 들일 때는 '숫자' 꼴임
    y = np.append(y,1*float(y_))
    z = np.append(z,1*float(z_))
    
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, aspect = 'equal', projection='3d')
ax.set_proj_type('ortho')
ax.scatter(x, y, z, c='r', marker='o')

axis_max = 1.5
axis_min = 1
#ax.set_xlim(-axis_min,axis_max)
#ax.set_ylim(-axis_min,axis_max)
#ax.set_zlim(-axis_min,axis_max)
#ax.set_xlim(-4,4)
#ax.set_ylim(-4,4)
#ax.set_zlim(-40,40)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_aspect('equal')
set_axes_equal(ax)
plt.show()
